# %%
age=17
if age>=18: # True
    print("Now in IF condition")
    print("Vote")
else:
    print("I am else block")
print("Hello Outside If block")
# Out:
# I am else block
# Hello Outside If block

# %%
age=15
if age >=18:
    print("You can Vote")
print("Program Finished")
# Out:
# Program Finished

# %%
x=10
if x> 50:
    print("Greater")
    print("Valid")
print("Done")
# Out:
# Done

# %%
number=8

if number%2==0:
    print("Even Number")
else:
    print("Odd number")

# %%
correct=1234
enter_password=int(input("Enter password"))
if enter_password==correct:
    print("Access Granted")
else:
    print("wrong Password")
# Out:
# Access Granted

# %%
age=12
citizen="Indian"

if age>=18:
    if citizen=="Indian":
        print("You are Eligible to Vote")
    else:
        print("Great! you are greater then 18...But you are not eligible to vote- Check your cititzenship")
else:
    print("You are underage")
# Out:
# You are underage

# %% [markdown]
# IF ELIF - ELSE
#
# if condition:
#     #Block1
# elif condition:
#     #Block2
#
# elif condition:
#     #Block3
#
# else:
#     Default Block

# %%
marks=85
if marks>=90:
    print("Outstanding")
elif marks>=75:
    print("First Division")
else:
    print("Pass")
# Out:
# First Division

# %%
number=32

if number>=20:
    print("Greater than 20")
elif number>=10:
    print("Greater Than 10")
elif number >=5:
    print("Greater than 5 ")
else:
    print("Small number ")
# Out:
# Greater than 20

# %%
marks = int(input("Please enter the marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 40:
    print("Grade D")
else:
    print("Fail")
# Out:
# Fail

# %%
Experience = int(input("Experience: "))

Salary = int(input("User_Salary: "))

 

if Experience >= 10:

    print(f"20% hike: {Salary * 20/100 + Salary}")

elif Experience >= 5:

    print(f"10% hike: {Salary * 10/100+ Salary}")

elif Experience >= 2:

    print(f"5% hike: {Salary * 5/100+ Salary}")

else:

    print("NoHike")
# Out:
# 10% hike: 0.0

# %%
exp = int(input("No of experience"))

salary = 10000

if exp >= 10:

    print("20% bonus")

    up_sal = salary+salary*0.2

    print(up_sal)

elif exp >= 5:

    print("10% grade")

    up_sal =salary+salary*0.1

    print(up_sal)

elif exp >= 2:

    print("5% bonus")

    up_sal =salary+salary*0.05

    print(up_sal)

else:

    print("No bonus")
# Out:
# 10% grade
# 11000.0

# %%
xp = int(input())

salary = int(input())

if exp >=10:

  bonus= salary * 0.20

  total_salary = bonus + salary

  print(total_salary)

elif exp >=5:

  bonus = salary * 0.10

  total_salary_1 = bonus + salary

  print(total_salary_1)

elif exp >=2:

  bonus = salary * 0.10

  total_salary_2 = bonus + salary

  print(total_salary_2)

else:

  print("no bonus")
# Out:
# 11000.0

# %%
age=int(input("Enter your age"))

if age < 0:
    print("Invalid Age")
elif age<=12:
    print("Child")
elif age<=19:
    print("Teenager")
elif age<=59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
username="admin"
password="python123"

if username=="admin":
    print("Usename Verified")
    if password=="python1234":
        print("Login Successful")
    else:
        print("Recheck your password")
else:
    print("Usename is Incorrect")
# Out:
# Usename Verified
# Recheck your password

# %%
salary=40000
experince=5

if salary>=50000:
    print("salary criteria passed")
    if experince>=3:
        print("Loan Approved")
    else:
        print("Your loan is not Approved! You should have more then or equals to 3 years experince")
else:
    print("salary criteria Not passed")
# Out:
# salary criteria Not passed

# %%
file_exists=True
record_count=0

if file_exists:
    print("File Found")

    if record_count>0:
        print("start ETl Process")
    else:
        print("Record Count is 0 )")
else:
    print("File Does not exists")
# Out:
# File Found
# Record Count is 0 )
