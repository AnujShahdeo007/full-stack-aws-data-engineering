# %% [markdown]
# object
# │
# ├── Numeric Types
# │   ├── int
# │   ├── float
# │   └── complex
# │
# ├── Boolean Type
# │   └── bool
# │
#
# │├── Sequence Types
# │   ├── str
# │   ├── list
# │   ├── tuple
# │   └── range
# ├── Mapping Type
# │   └── dict
# │
# ├── Set Types
# │   ├── set
# │   └── frozenset
# │
# ├── Binary Types
# │   ├── bytes
# │   ├── bytearray
# │   └── memoryview
# │
# └── Special Type
#     └── NoneType

# %% [markdown]
# ├── Numeric Types
# │   ├── int - Whole number
# │   ├── float - Decimal number
# │   └── complex - a+bj - x=3+4j

# %%
# In python everything object 
a=10
b=10.5
c="Rahul"
d=[1,2,3]

# %%
print(type(10))
print(type(10.5))
print(type("Rahul"))
print(type([1,2,3]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>

# %%
x=3+4j
print(type(x))
# Out:
# <class 'complex'>

# %%
print(x.real)
# Out:
# 3.0

# %%
print(x.imag)
# Out:
# 4.0

# %%
# ├── Sequence Types
# │   ├── str
# │   ├── list
# │   ├── tuple
# │   └── range

# %%
name="Rahul"

# %%
print(name[0])
# Out:
# R

# %%
print(name[1])
# Out:
# a

# %%
print(name[3])
# Out:
# u
