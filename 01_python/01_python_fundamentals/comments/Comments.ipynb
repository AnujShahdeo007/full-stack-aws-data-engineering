# %%
print("hello") 
# This is a comment
# Out:
# hello

# %%
salary=50000
# Calculate 20% tax 
tax=salary*0.2 # Calculate
#Deduct tax from salary
final_salary=salary-tax
print(final_salary)
"""
This script reads emplyeee data 
Validates records 
Loads records into db 
Send notifactions 
"""

'''
This script reads emplyeee data 
Validates records 
Loads records into db 
Send notifactions 
'''
# Out:
# 40000.0
# '\nThis script reads emplyeee data \nValidates records \nLoads records into db \nSend notifactions \n'

# %% [markdown]
# Types:
#
#     - Single line comment
#         - #
#     - Inline comment
#         - Comment written on the same line
#         - tax=salary*0.2 # Calculate
#     - Multi line comment
#
#         -
