# %%
x="10.5"#str
y=int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 x="10.5"#str
# ----> 2 y=int(x)
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
y=float(x)

# %%
y
# Out:
# 10.5

# %%
z=int(y)

# %%
z
# Out:
# 10

# %%
x=10
y=float(x)

# %%
y
# Out:
# 10.0

# %%
x="25.67"
y=float(x)

# %%
x="100"
y=float(x)

# %%
y
# Out:
# 100.0

# %%
x=100
y=str(x)

# %%
y
# Out:
# '100'

# %%
x="100"
print(x)
# Out:
# 100

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
y=int(x)

# %%
print(y)
# Out:
# 100

# %%
print(type(y))
# Out:
# <class 'int'>

# %% [markdown]
# Rule 1: Conversion Must make sense : Python only converts when conversion is logically possible
#
# int("100") # Valid # 100
#
# int("hello") # valueError
#
#
# Rule 2: input() Always return string
#
#
# Rule 3: int() Accepts Only interger value
#
# int("100")
# int("-50")
# int("+20")
#
# int("10.5") # Fails Value Error
#
# Rule 4 : int() Removes Decimal part
#
# int(10.9) # 9
#
# int(99.99) # 99
#
# Rule 5 : float() can accept integer and decimal Strings
#
# float("100") # 100.0
# float("100.5") # 100.5
#
# flaot ("abc") # fails
#
#
# Rule 6: str() can convert Almost Anything
#
# str(100)
# str(10.5)
# str(True)
# Str([1,2,3])
#
# Rule 7 Bollen Conversion Rule
#
# bool(0)
# bool(0.0)
# bool("")
# bool([])
# bool({})
# bool(())
# bool(None)
#
# Output : False
#
# Eveything else become True:
#
# bool(1)
# bool(-10)
# bool("Hello")
# bool([1,2])
#
#
# Rule 8: list(),tuple(),set() Need Iterable Objects ***********************************************************
#
#
# Rule 9: Set() *************************************
#
#
# Rule: 10 Implicit Type Casting Follows Higher Precision :
#
# Numeric Type :
#
# bool
#
# int
#
# float
#
# complex
#
# bool < int < float < complex

# %%
bool(False)
# Out:
# False

# %%
print(True+5)
# Out:
# 6

# %%
print(5+10.8)
# Out:
# 15.8

# %%
t=(10.5+2j)

# %%
print(type(t))
# Out:
# <class 'complex'>
