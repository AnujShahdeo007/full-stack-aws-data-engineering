# %% [markdown]
# name="abc"

# %%
x=10

# %%
x
# Out:
# 10

# %%
y=x

# %%
y
# Out:
# 10

# %%
print(id(x))
# Out:
# 4352767616

# %%
print(x)
# Out:
# 10

# %%
print(id(y))
# Out:
# 4345034368

# %%
bucket_name = "sales-prod-bucket"
source_file = "sales_data.csv"
api_url= "https://api.example.com/data"
table_name = "sales_data"

# %%
bucket_name
# Out:
# 'sales-prod-bucket'

# %%
upload_file(bucket_name)
download_file(bucket_name)
df=spark.read.csv(source_file, header=True, inferSchema=True)

# %%
query = f"SELECT * FROM {table_name} WHERE date >= '2023-01-01'"

# %%
query
# Out:
# "SELECT * FROM sales_data WHERE date >= '2023-01-01'"

# %%
age=30
salary=50000.0
name="hello"
is_active=True

# %% [markdown]
# name="Rahul"
#
# x=x+1 invalid
#
# x=10
# x=x+1
#
#
# Naming Rules:
#
# Rule :1 Must start with Letter
#
# name="Rahul"
# salary=5000
# city="pune"
#
# a-z
# A-Z
# _
#
#
# _name="rahul"
#
#
# Rule2: Underscore Allowed
#
# _total_salary=5000
#
# emp_name
#
# Rule 3: Cannot start with Number
#
# 1name="Rahul"
# 123name="rahul"
#
#
# Rule 4 : No space Allowed
#
# emp name="rahul"
#
# Rule 5: No special charcater
#
# salary@
# city#
# name&$
#
# Rule 6 : Keyword cannot be used
#
# if
# else
# for
# while
# try
# expect
# return
# import

# %%
x=10 
x=x+10

# %%
1name="rahul"
# Out:
#   Cell In[10], line 1
#     1name="rahul"
#     ^
# SyntaxError: invalid decimal literal

# %%
_name="rahul"

# %%
emp_name="rahul"

# %%
import =10
# Out:
#   Cell In[14], line 1
#     import =10
#            ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
class_1="hello"
print(class_1)
print(Class_1)
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 class_1="hello"
#       2 print(class_1)
# ----> 3 print(Class_1)
#
# NameError: name 'Class_1' is not defined

# %%
employee_name="rahul"
employee_name="rahul"

# %% [markdown]
# # Dynamic Typing
#
#     # Data Type
#
#     INTEGER - Whole numbers = 100,0,-50,200
#
#     FLOAT - Decimal number = 700.87
#
#     STRING - TEXT data
#
#     BOOLEAN - TRUE/FALSE

# %%
x=10
name="Rahul"

# %%
name="Rahul"

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
age=30

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
salary=50000.0

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
is_active=True

# %%
print(type(is_active))
# Out:
# <class 'bool'>

# %%
x=10 #int
print(type(x))
x="Rahul"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
temperature=25
print(type(temperature))
temperature=25.5
print(type(temperature))
# Out:
# <class 'int'>
# <class 'float'>

# %%
age="30"
result=age+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 age="30"
# ----> 2 result=age+10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Multiple Variable Assignment, Variable Unpacing & Swapping

# %%
name="Rahul"
age=30
city="Pune"

# %%
name
# Out:
# 'Rahul'

# %%
name,age,city="Hello",30,"Pune"

# %%
name
# Out:
# 'Hello'

# %%
age
# Out:
# 30

# %%
city
# Out:
# 'Pune'

# %%
region,bucket,table=(
    "Us-east-1",
    "sales-prod-bucket",
    "sales_data"
)

# %%
region
# Out:
# 'Us-east-1'

# %%
bucket
# Out:
# 'sales-prod-bucket'

# %%
a,b,c=1,2,3

# %%
a,b,c=1,2,3,4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a,b,c=1,2,3,4
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b=1,2,3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a,b=1,2,3
#
# ValueError: too many values to unpack (expected 2)

# %%
a=10
b=10
c=10

# %%
a
# Out:
# 10

# %%
b
# Out:
# 10

# %%
c
# Out:
# 10

# %%
a=b=c=20

# %%
a
# Out:
# 20

# %%
b
# Out:
# 20

# %%
c
# Out:
# 20

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 4345083840
# 4345083840
# 4345083840

# %%
employee=("Rahul",30,"Pune")

# %%
employee[0]
# Out:
# 'Rahul'

# %%
employee[1]
# Out:
# 30

# %%
name,age,city=employee

# %%
name
# Out:
# 'Rahul'

# %%
age
# Out:
# 30

# %%
response=("SUCESS",200,"Records Loaded")

# %%
status,code,message=response

# %%
status
# Out:
# 'SUCESS'

# %%
a=10
b=20

# %%
temp=a

# %%
a=b

# %%
a
# Out:
# 20

# %%
b=temp

# %%
b
# Out:
# 10

# %%
a=50
b=100

# %%
a
# Out:
# 50

# %%
b
# Out:
# 100

# %%
a,b=b,a

# %%
a
# Out:
# 100

# %%
b
# Out:
# 50

# %%
numbers=[10,20,30,40,50]
first,*middle,last=numbers

# %%
first
# Out:
# 10

# %%
last
# Out:
# 50

# %%
middle
# Out:
# [20, 30, 40]

# %%
a=["Rahul","Python","Spark","SQL"]
name,*skills=a

# %%
name
# Out:
# 'Rahul'

# %%
skills
# Out:
# ['Python', 'Spark', 'SQL']

# %%
raw=["101","Rahul","Pune","India","Engineer"]

# %%
id,name,*details=raw

# %%
id
# Out:
# '101'

# %%
name
# Out:
# 'Rahul'

# %%
details
# Out:
# ['Pune', 'India', 'Engineer']

# %%
numbers=[10,20,30,40,50]
a,b,c,d,e=numbers

# %%
numbers=[10,20,30,40,50]
a,b,c=numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 numbers=[10,20,30,40,50]
# ----> 2 a,b,c=numbers
#
# ValueError: too many values to unpack (expected 3)

# %%
a,*b=numbers

# %%
a
# Out:
# 10

# %%
b
# Out:
# [20, 30, 40, 50]

# %%
*a,b=numbers

# %%
a
# Out:
# [10, 20, 30, 40]

# %%
b
# Out:
# 50

# %%
def show():
    salary=50000 # local variable
    print(salary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 4
#       2     salary=50000
#       3     print(salary)
# ----> 4 print(salary)
#
# NameError: name 'salary' is not defined

# %%
show()
# Out:
# 50000

# %%
salary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 salary
#
# NameError: name 'salary' is not defined

# %%
salary=100000 # global variable
def show1(salary):
    print(salary)  

def show2(salary):
    print(salary)

# %%
show1(salary)
# Out:
# 100000

# %%
show2(salary)
# Out:
# 100000

# %% [markdown]
# Immutable Objects
#
# int
# float
# str
# bool
# tuple
# frozenset

# %%
x=10

# %%
name="Rahul"
name[0]="A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 name="Rahul"
# ----> 2 name[0]="A"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Mutable Object
#
# list
# dict
# set
# bytearray

# %%
numbers=[10,20,30,40,50]

# %%
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers.append(60)

# %%
numbers
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
num1=[10,20,30]

# %%
num1
# Out:
# [10, 20, 30]

# %%
print(id(num1))
# Out:
# 4496258496

# %%
num1.append(60)

# %%
print(id(num1))
# Out:
# 4496258496
